# %% [markdown]
# #**Deep Learning NCU** - **Final Project Group 12**

# %% [markdown]
# ***DATASET : BRAIN TUMOR IMAGE***

# %% [markdown]
# **Group Members :**
#
#
# *   Anthonin Guillaume (**114522902**)
# *   Lynna Moussaoui (**114522906**)
# *   Lina Bachir Belarbi (**114522903**)
# *   Saïd GRAJA (**114522901**)

# %% [markdown]
# ## Introduction
#
# In this project, we work with the Brain Tumor Image Dataset – Semantic Segmentation from Kaggle.
# The goal is to train deep learning models that can detect and segment brain tumors in MRI images.
# Each image has a corresponding mask that shows the tumor region, so this is a semantic segmentation task.
#
# In this project, we wanted to explore models and loss functions that we had not discussed in class and had not implemented before. Based on our research, U-Net is one of the most commonly used models for image segmentation. For this task, Dice and IoU are suitable metrics to evaluate performance.
#
# We also wanted to assess the relevance of using pretrained models (transfer learning). Finally, we compared Tversky loss and Focal loss, which we had never implemented before.
#
#
# Our approach has three main steps:
#
# 1. **Baseline model (U-Net from scratch)**
#    We first build a simple U-Net model without pre-trained weights.
#    This gives us a  baseline to understand the dataset, the training pipeline,
#    and the basic performance (Dice / IoU scores and visual results).
#
#
# 2. **Transfer learning with a pre-trained backbone**
#    Next, we use a U-Net with a backbone pre-trained on ImageNet (for example ResNet34).
#    The idea is to reuse low-level and mid-level features learned on a large dataset,
#    and check if this improves convergence and segmentation quality on medical images.
#
#
# 3. **Loss function comparison for imbalanced data**
#    Because the tumor area is often much smaller than the background,
#    we study different loss functions designed for imbalanced segmentation:
#    Binary Cross-Entropy + Dice, Focal Loss, and Tversky-based losses.
#    We compare their impact on Dice / IoU and on the detection of small tumors.
#
# With this workflow, we connect several topics from the deep learning course:
# convolutional neural networks for vision, optimization and regularization,
# transfer learning, and the choice of loss functions for imbalanced data.

# %% [markdown]
# # **`GitHub Management`**

# %% [markdown]
# ##**Submission in the Github ripestory**

# %%
# Cloner le repo depuis GitHub
# !git clone https://github.com/EnseaStudent/Final-Project-Brain-Tumor-Image-DataSet-Semantic-Segmentation-.git

# Aller dans le dossier du projet
# %cd Final-Project-Brain-Tumor-Image-DataSet-Semantic-Segmentation-
# Out:
# Cloning into 'Final-Project-Brain-Tumor-Image-DataSet-Semantic-Segmentation-'...
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 8 (delta 0), reused 6 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (8/8), 443.79 KiB | 994.00 KiB/s, done.
# /content/Final-Project-Brain-Tumor-Image-DataSet-Semantic-Segmentation-

# %%
# !git config --global user.email "said.graja@ensea.fr"
# !git config --global user.name "EnseaStudent"

# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
# === A. Monter le Drive + cloner le repo dans ton dossier de projet ===
from google.colab import drive
drive.mount('/content/drive')

# Aller dans ton dossier de projet sur le Drive
# %cd "/content/drive/MyDrive/Group Project DL/Collab"

# Supprimer une éventuelle ancienne copie du repo
# !rm -rf Final-Project-Brain-Tumor-Image-DataSet-Semantic-Segmentation-

# Cloner le repo GitHub DANS le Drive
# !git clone https://github.com/EnseaStudent/Final-Project-Brain-Tumor-Image-DataSet-Semantic-Segmentation-.git

# Copier ton notebook existant dans le repo
# !cp "main.ipynb" "Final-Project-Brain-Tumor-Image-DataSet-Semantic-Segmentation-/main.ipynb"

# Aller dans le repo
# %cd "Final-Project-Brain-Tumor-Image-DataSet-Semantic-Segmentation-"

# Vérifier l'état Git
# !git status

# %%
TOKEN = "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"

# %%
import os, getpass

# 1) Aller dans le dossier du repo (au cas où)
# %cd "/content/drive/MyDrive/Group Project DL/Collab/Final-Project-Brain-Tumor-Image-DataSet-Semantic-Segmentation-"

# 2) Vérif sécurité : pas de token GitHub dans le notebook
with open("main.ipynb", "r", encoding="utf-8") as f:
    content = f.read()




# 3) Config Git (au cas où)
# !git config user.email "said.graja@ensea.fr"
# !git config user.name "EnseaStudent"

# 4) Commit de main.ipynb
# !git add main.ipynb
# !git commit -m "Add main.ipynb for DL final project"

# 5) Demander ton nouveau PAT (token GitHub) de façon sécurisée
token = getpass.getpass("Nouveau GitHub PAT (scope repo) : ")
os.environ["GITHUB_TOKEN"] = token

# 6) Push vers GitHub (sans enregistrer le token dans la config)
# !git push https://github.com/EnseaStudent/Final-Project-Brain-Tumor-Image-DataSet-Semantic-Segmentation-

# %%
import os
import nbformat as nbf

# 1) Aller dans le repo
# %cd "/content/drive/MyDrive/Group Project DL/Collab/Final-Project-Brain-Tumor-Image-DataSet-Semantic-Segmentation-"

# 2) Nettoyer le notebook pour que GitHub arrête de dire "Invalid Notebook"
nb_path = "main.ipynb"
nb = nbf.read(nb_path, as_version=4)
if "widgets" in nb.metadata:
    del nb.metadata["widgets"]
nbf.write(nb, nb_path)

# 3) Commit
# !git add main.ipynb
# !git commit -m "Update main.ipynb"

# 4) Push avec le token déjà stocké dans la variable Python TOKEN
os.environ["GITHUB_TOKEN"] = TOKEN # Use GITHUB_TOKEN for consistency
# !git push origin main

# %%
# %cd /content/drive/MyDrive/Group Project DL/Collab
# !ls

# %%
# !cp "main.ipynb" "/content/Final-Project-Brain-Tumor-Image-DataSet-Semantic-Segmentation-/"

# %%
# !git status
# !git add main.ipynb
# !git commit -m "11/12/2025 version"
# !git push origin main.ipynb

# %%
# 1) Copier le notebook que tu édites (Drive) vers le repo git
# !cp "/content/drive/MyDrive/Group Project DL/Collab/main.ipynb" \
    "/content/Final-Project-Brain-Tumor-Image-DataSet-Semantic-Segmentation-/main.ipynb"

# 2) Aller dans le dossier du repo
# %cd /content/Final-Project-Brain-Tumor-Image-DataSet-Semantic-Segmentation-

# 3) Commit + push
# !git status
# !git add main.ipynb
# !git commit -m "11/12/2025 version"
# !git push origin main

# %%
# === Push propre de main.ipynb vers GitHub depuis Colab ===

from google.colab import drive
import os

# 1) Monter le Drive
#drive.mount('/content/drive')

# 2) Chemins
repo_path = "/content/Final-Project-Brain-Tumor-Image-DataSet-Semantic-Segmentation-"
nb_src = "/content/drive/MyDrive/Group Project DL/Collab/main.ipynb"
nb_dst = f"{repo_path}/main.ipynb"

# 3) Aller dans le repo
os.chdir(repo_path)

# 4) S’aligner sur le serveur (au cas où un vieux commit local traîne)
# !git fetch origin
# !git reset --soft origin/main

# 5) Copier la dernière version du notebook depuis le Drive vers le repo
# !cp "{nb_src}" "{nb_dst}"

# %% [markdown]
# # **`Import & Analysis of the Dataset`**

# %% [markdown]
# ##**Import**

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("pkdarabi/brain-tumor-image-dataset-semantic-segmentation")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'brain-tumor-image-dataset-semantic-segmentation' dataset.
# Path to dataset files: /kaggle/input/brain-tumor-image-dataset-semantic-segmentation

# %% [markdown]
# ##**Display & Aalysis of the Dataset**

# %%
import os
import json
import random
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

# %%
# Root folder given by kagglehub
root = Path(path)


# Inspect folder structure

print("\nLevel-1 content:")

for p in root.iterdir():
    print("  -", p)

print("\nLevel-2 content:")

for p in root.rglob("*"):
    if p.is_dir():
      print("  -", p.name)
# Out:
# Level-1 content:
#   - /kaggle/input/brain-tumor-image-dataset-semantic-segmentation/README.txt
#   - /kaggle/input/brain-tumor-image-dataset-semantic-segmentation/valid
#   - /kaggle/input/brain-tumor-image-dataset-semantic-segmentation/test
#   - /kaggle/input/brain-tumor-image-dataset-semantic-segmentation/train
#
# Level-2 content:
#   - valid
#   - test
#   - train

# %%
# List all JPG images and basic stats

image_files = sorted(root.rglob("*.jpg"))

print(f"\nTotal JPG images found: {len(image_files)}")

def get_split(p: Path) -> str:

    parts = [part.lower() for part in p.parts]
    for split in ["train", "valid", "val", "test"]:
        if split in parts:
            return "val" if split == "valid" else split
    return "unknown"


df_imgs = pd.DataFrame({"path": image_files})
df_imgs["split"] = df_imgs["path"].apply(get_split)

print("\nImage count by split:")
print(df_imgs["split"].value_counts())
# Out:
# Total JPG images found: 2146
#
# Image count by split:
# split
# train    1502
# val       429
# test      215
# Name: count, dtype: int64

# %%
# Look for JSON annotation files (COCO-style)


json_files = list(root.rglob("*.json"))

print("\nJSON / annotation files found:")

if not json_files:
    print("  → No JSON file found (maybe masks are stored as images).")
else:
    for jf in json_files:
        print("  -", jf)

    # Simple analysis on the first JSON file
    ann_path = json_files[0]
    print("\nTrying to read COCO-style annotations from:", ann_path)

    with open(ann_path, "r") as f:
        coco = json.load(f)

    images_df = pd.DataFrame(coco.get("images", []))
    ann_df = pd.DataFrame(coco.get("annotations", []))
    cats_df = pd.DataFrame(coco.get("categories", []))

    if not ann_df.empty and not cats_df.empty:
        print("\nCategories:")
        print(cats_df[["id", "name"]])

        ann_df = ann_df.merge(
            cats_df,
            left_on="category_id",
            right_on="id",
            suffixes=("", "_cat"),
        )
        cat_counts = ann_df["name"].value_counts()
        print("\nNumber of annotations per category:")
        print(cat_counts)
    else:
        print("Annotations or categories are empty, maybe a different format.")
# Out:
# JSON / annotation files found:
#   - /kaggle/input/brain-tumor-image-dataset-semantic-segmentation/valid/_annotations.coco.json
#   - /kaggle/input/brain-tumor-image-dataset-semantic-segmentation/test/_annotations.coco.json
#   - /kaggle/input/brain-tumor-image-dataset-semantic-segmentation/train/_annotations.coco.json
#
# Trying to read COCO-style annotations from: /kaggle/input/brain-tumor-image-dataset-semantic-segmentation/valid/_annotations.coco.json
#
# Categories:
#    id   name
# 0   0  Tumor
# 1   1      0
# 2   2      1
#
# Number of annotations per category:
# name
# 1    219
# 0    210
# Name: count, dtype: int64

# %%
# --- 4. Show a few sample images ---
if len(image_files) > 0:
    n_samples = min(4, len(image_files))
    sample_paths = random.sample(image_files, k=n_samples)

    print(f"\nDisplaying {n_samples} random images:")

    fig, axes = plt.subplots(1, n_samples, figsize=(4 * n_samples, 4))
    if n_samples == 1:
        axes = [axes]

    for ax, img_path in zip(axes, sample_paths):
        img = Image.open(img_path).convert("RGB")
        ax.imshow(img)
        ax.set_title(img_path.name, fontsize=8)
        ax.axis("off")

    plt.tight_layout()
    plt.show()
# Out:
# Displaying 4 random images:

# %% [markdown]
# ### Dataset structure analysis
#
# The dataset is well organized in three splits:
#
# - **Train:** 1502 images
# - **Validation:** 429 images
# - **Test:** 215 images
#
# This is roughly a 70 / 20 / 10 split, which is a good ratio for training, tuning, and final evaluation.
# In total, we have **2146 MRI images** of the brain.
#
# Each split also contains a `_annotations.coco.json` file.
# These files use a COCO-style format with three categories: `Tumor`, `0`, and `1`.
# The annotation counts in the validation set are:
#
# - 219 annotations for category `1`
# - 210 annotations for category `0`
#
# This means that almost all images have at least one annotated region, and the task is a binary segmentation (tumor vs background), even if the labels are stored with several category names.
#
# Later in the project, we will simplify these categories and treat the problem as tumor / non-tumor segmentation.
#
# From the visual samples, we also see that the tumor area is usually much smaller than the rest of the brain.
# This suggests a strong class imbalance at the pixel level, which is an important point for our work on loss functions (Dice, Focal, Tversky).

# %% [markdown]
# # **`CODE`**

# %% [markdown]
# #`1. Baseline model`

# %% [markdown]
# ## Step 1 – Baseline U-Net (from scratch)
#
#
# In this section, we train a first baseline model for tumor segmentation.
#
# We use a 2D U-Net architecture implemented with `segmentation-models-pytorch`.
# The encoder is a ResNet34 **without pre-trained weights**, so this is really a
# “from scratch” baseline.
#
# Images are resized and normalized, and we create binary masks from the COCO
# annotations (tumor = 1, background = 0).
# We train the model on the train split and evaluate it on the validation split
# with Dice and IoU scores.

# %% [markdown]
# ###**Install libraries** OK

# %%
# !pip install -q segmentation-models-pytorch==0.5.0 \
                 timm==1.0.22 \
                 albumentations==1.4
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 8.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.6/123.6 kB 12.5 MB/s eta 0:00:00

# %% [markdown]
# In this cell, we install the main libraries needed for our project.
# We use `segmentation-models-pytorch` to create a U-Net model. We install `timm` because it will be useful later for pre-trained backbones. We also install `albumentations` to apply data augmentation on the images.

# %% [markdown]
# ###***Dataset class + transforms*** OK

# %%
import os
import json
from pathlib import Path

import numpy as np
from PIL import Image, ImageDraw

import torch
from torch.utils.data import Dataset, DataLoader
import albumentations as A

# Root folders from kagglehub path
DATA_ROOT = Path(path)          # 'versions/1'
TRAIN_DIR = DATA_ROOT / "train"
VAL_DIR   = DATA_ROOT / "valid"
TEST_DIR  = DATA_ROOT / "test"

print("Train dir:", TRAIN_DIR)
print("Val dir:", VAL_DIR)
print("Test dir:", TEST_DIR)


def get_transforms(train: bool = True, img_size: int = 256):
    """Augmentations + normalisation."""
    if train:
        return A.Compose(
            [
                A.Resize(img_size, img_size),
                A.HorizontalFlip(p=0.5),
                A.RandomRotate90(p=0.5),
                A.ShiftScaleRotate(
                    shift_limit=0.05,
                    scale_limit=0.05,
                    rotate_limit=15,
                    p=0.5,
                    border_mode=0,
                ),
                A.Normalize(mean=(0.5, 0.5, 0.5),
                            std=(0.5, 0.5, 0.5)),
            ]
        )
    else:
        return A.Compose(
            [
                A.Resize(img_size, img_size),
                A.Normalize(mean=(0.5, 0.5, 0.5),
                            std=(0.5, 0.5, 0.5)),
            ]
        )


class BrainTumorSegmentationDataset(Dataset):
    """
    Dataset for COCO-style annotations.
    We build a binary mask: tumor pixels = 1, background = 0.
    """

    def __init__(self, split_dir: Path, transforms=None):
        self.split_dir = split_dir
        self.transforms = transforms

        # Load COCO json
        ann_path = split_dir / "_annotations.coco.json"
        with open(ann_path, "r") as f:
            coco = json.load(f)

        self.images = coco["images"]
        self.annotations = coco["annotations"]

        # Map image_id -> list of annotations
        self.ann_by_image = {}
        for ann in self.annotations:
            img_id = ann["image_id"]
            self.ann_by_image.setdefault(img_id, []).append(ann)

        # For quick file path lookup
        self.id_to_file = {img["id"]: img["file_name"] for img in self.images}

        print(f"{split_dir.name}: {len(self.images)} images")

    def __len__(self):
        return len(self.images)

    def _build_mask(self, img_info):
        """Create binary mask from polygon segmentations."""
        w, h = img_info["width"], img_info["height"]
        img_id = img_info["id"]

        mask = Image.new("L", (w, h), 0)
        draw = ImageDraw.Draw(mask)

        anns = self.ann_by_image.get(img_id, [])

        # We treat all polygons as tumor regions (class = 1)
        for ann in anns:
            segs = ann.get("segmentation", [])
            for seg in segs:
                # seg is [x1, y1, x2, y2, ...]
                xy = [(seg[i], seg[i + 1]) for i in range(0, len(seg), 2)]
                draw.polygon(xy, outline=1, fill=1)

        return np.array(mask, dtype=np.uint8)

    def __getitem__(self, idx):
        img_info = self.images[idx]
        file_name = img_info["file_name"]
        img_path = self.split_dir / file_name

        # Load image (RGB)
        image = Image.open(img_path).convert("RGB")
        image = np.array(image)

        # Build mask
        mask = self._build_mask(img_info)  # H x W, values in {0,1}

        # Apply transforms (Albumentations works on numpy)
        if self.transforms is not None:
            augmented = self.transforms(image=image, mask=mask)
            image = augmented["image"]
            mask = augmented["mask"]

        # To torch tensors
        image = torch.from_numpy(image.transpose(2, 0, 1)).float() / 255.0
        mask = torch.from_numpy(mask).unsqueeze(0).float()  # 1 x H x W

        return image, mask
# Out:
# Train dir: /kaggle/input/brain-tumor-image-dataset-semantic-segmentation/train
# Val dir: /kaggle/input/brain-tumor-image-dataset-semantic-segmentation/valid
# Test dir: /kaggle/input/brain-tumor-image-dataset-semantic-segmentation/test

# %% [markdown]
# In this cell, we prepare everything needed to read the dataset and create training samples for the model. First, we set the main folders for the train, validation and test splits using the path given by Kaggle. Then we define the `get_transforms` function. It resizes all images to a fixed size and, for the training set, it also applies random flips, rotations and small geometric changes. This helps the model to see slightly different versions of the same image and improves generalization. At the end, we normalize the pixel values.
#
# The `BrainTumorSegmentationDataset` class reads the COCO annotation file `_annotations.coco.json` inside each split. For every image, it collects all polygon annotations and uses them to draw a binary mask where tumor pixels are equal to 1 and background pixels are equal to 0. The same transforms are applied to both the image and the mask. Finally, the image and the mask are converted to PyTorch tensors with the right shapes, so that they can be used directly as input and target for the U-Net model during training.

# %% [markdown]
# ###***Dataloaders + device*** OK

# %%
IMG_SIZE = 256
BATCH_SIZE = 8

train_ds = BrainTumorSegmentationDataset(
    TRAIN_DIR,
    transforms=get_transforms(train=True, img_size=IMG_SIZE),
)
val_ds = BrainTumorSegmentationDataset(
    VAL_DIR,
    transforms=get_transforms(train=False, img_size=IMG_SIZE),
)

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE,
                          shuffle=True, num_workers=0, pin_memory=True)
val_loader = DataLoader(val_ds, batch_size=BATCH_SIZE,
                        shuffle=False, num_workers=0, pin_memory=True)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# train: 1502 images
# valid: 429 images
# device(type='cuda')

# %% [markdown]
# In this cell, we create the DataLoaders for the training and validation sets.
# The DataLoader takes our custom dataset and groups the samples into mini-batches of fixed size.
# For the training loader, we shuffle the data so that the model sees the images in a different order at each epoch.
# We set `num_workers = 0` to avoid multiprocessing issues in Colab.
#
# We also detect if a GPU is available.
# If a GPU is found, we use the `cuda` device; otherwise, we use the CPU.
# This `device` variable will be used later to move the model and the tensors to the correct hardware.

# %% [markdown]
# ###***U-Net model, lost funct & metrics*** OK

# %%
import torch.nn as nn
import segmentation_models_pytorch as smp

# U-Net baseline: ResNet34 encoder without pretraining
model = smp.Unet(
    encoder_name="resnet34",
    encoder_weights=None,
    in_channels=3,
    classes=1,              # binary mask
)
model = model.to(device)

bce_loss = nn.BCEWithLogitsLoss()

def dice_coeff(preds, targets, eps=1e-7):
    """
    Dice coefficient for binary segmentation.
    preds: logits (B,1,H,W)
    """
    probs = torch.sigmoid(preds)
    preds_bin = (probs > 0.5).float()

    intersection = (preds_bin * targets).sum(dim=(1, 2, 3))
    union = preds_bin.sum(dim=(1, 2, 3)) + targets.sum(dim=(1, 2, 3))

    dice = (2 * intersection + eps) / (union + eps)
    return dice.mean()


def bce_dice_loss(preds, targets):
    """BCE + (1 - Dice) combined loss."""
    loss_bce = bce_loss(preds, targets)
    dice = dice_coeff(preds, targets)
    return loss_bce + (1.0 - dice), loss_bce, dice

# %% [markdown]
# U-Net model and loss functions
#
# Here we define our baseline segmentation model and the loss functions.
# We create a 2D U-Net using `segmentation-models-pytorch` with a ResNet34 encoder.
# We do not use pre-trained weights, so the network is trained from scratch.
# The model outputs one channel per pixel, which represents the score for the tumor class.
#
# We also define `BCEWithLogitsLoss` as a pixel-wise binary classification loss.
# In addition, we implement a function to compute the Dice coefficient, which measures the overlap between the predicted mask and the ground truth mask.
# Finally, we combine these two ideas in `bce_dice_loss`, which returns a total loss equal to the BCE loss plus (1 − Dice).
# This combined loss encourages the model to classify each pixel correctly and to maximize the overlap between the predicted and true tumor regions.

# %% [markdown]
# ###***Training Loop*** OK

# %%
import torch.optim as optim
from tqdm.auto import tqdm

EPOCHS = 15
lr = 1e-4

optimizer = optim.Adam(model.parameters(), lr=lr)


def train_one_epoch(model, loader, optimizer, device):
    model.train()
    running_loss = 0.0
    running_dice = 0.0

    for images, masks in tqdm(loader, desc="Train", leave=False):
        images = images.to(device)
        masks = masks.to(device)

        optimizer.zero_grad()
        outputs = model(images)

        loss, bce, dice = bce_dice_loss(outputs, masks)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * images.size(0)
        running_dice += dice.item() * images.size(0)

    n = len(loader.dataset)
    return running_loss / n, running_dice / n


def evaluate(model, loader, device):
    model.eval()
    running_loss = 0.0
    running_dice = 0.0

    with torch.no_grad():
        for images, masks in tqdm(loader, desc="Val", leave=False):
            images = images.to(device)
            masks = masks.to(device)

            outputs = model(images)
            loss, bce, dice = bce_dice_loss(outputs, masks)

            running_loss += loss.item() * images.size(0)
            running_dice += dice.item() * images.size(0)

    n = len(loader.dataset)
    return running_loss / n, running_dice / n


baseline_history = {
    "train_loss": [],
    "val_loss": [],
    "train_dice": [],
    "val_dice": [],
}

best_val_dice_baseline = 0.0

for epoch in range(1, EPOCHS + 1):
    print(f"Epoch {epoch}/{EPOCHS}")

    train_loss, train_dice = train_one_epoch(model, train_loader, optimizer, device)
    val_loss, val_dice = evaluate(model, val_loader, device)

    print(f"Train loss: {train_loss:.4f}  |  Train Dice: {train_dice:.4f}")
    print(f"Val   loss: {val_loss:.4f}  |  Val   Dice: {val_dice:.4f}")

    # 🔹 On sauvegarde TOUTES les valeurs
    baseline_history["train_loss"].append(train_loss)
    baseline_history["val_loss"].append(val_loss)
    baseline_history["train_dice"].append(train_dice)
    baseline_history["val_dice"].append(val_dice)

    # 🔹 On continue quand même à garder le meilleur modèle
    if val_dice > best_val_dice_baseline:
        best_val_dice_baseline = val_dice
        torch.save(model.state_dict(), "unet_baseline_best.pth")
        print("  --> New best baseline model saved.")
# Out:
# Epoch 1/15
# ...
# Val:   0%|          | 0/54 [00:00<?, ?it/s]
# Train loss: 1.1775  |  Train Dice: 0.1516
# Val   loss: 1.0002  |  Val   Dice: 0.2239
#   --> New best baseline model saved.
# Epoch 2/15
# ...
# Val:   0%|          | 0/54 [00:00<?, ?it/s]
# Train loss: 0.7648  |  Train Dice: 0.4029
# Val   loss: 0.6548  |  Val   Dice: 0.4843
#   --> New best baseline model saved.
# Epoch 3/15
# ...
# Val:   0%|          | 0/54 [00:00<?, ?it/s]
# Train loss: 0.6279  |  Train Dice: 0.4916
# Val   loss: 0.5537  |  Val   Dice: 0.5507
#   --> New best baseline model saved.
# Epoch 4/15
# ...
# Val:   0%|          | 0/54 [00:00<?, ?it/s]
# Train loss: 0.5741  |  Train Dice: 0.5228
# Val   loss: 0.5146  |  Val   Dice: 0.5788
#   --> New best baseline model saved.
# Epoch 5/15
# ...
# Val:   0%|          | 0/54 [00:00<?, ?it/s]
# Train loss: 0.5187  |  Train Dice: 0.5642
# Val   loss: 0.5062  |  Val   Dice: 0.5705
# Epoch 6/15
# ...
# Val:   0%|          | 0/54 [00:00<?, ?it/s]
# Train loss: 0.4932  |  Train Dice: 0.5817
# ...

# %% [markdown]
# Training and validation loops
#
# This cell contains the main training and evaluation code for the baseline U-Net.
#
# The function `train_one_epoch` puts the model in training mode, loops over all training batches, computes the loss and Dice score, and updates the model weights using the Adam optimizer.
#
# The function `evaluate` puts the model in evaluation mode and loops over the validation batches without updating the weights.
# It computes the validation loss and Dice score to measure how well the model generalizes to unseen data.
#
# In the final loop over epochs, we train and evaluate the model several times.
# For each epoch, we print the training and validation metrics.
# When the validation Dice is better than all previous values, we save the model weights in the file `unet_baseline_best.pth`.
# This file stores the best version of our baseline model according to the validation performance.

# %% [markdown]
# Note about DataLoader workers:
#
# At the beginning, we used multiple workers in the PyTorch DataLoader
# (num_workers > 0).
#
# This created warning messages related to multiprocessing ("can only test a child process"). So we set `num_workers = 0` for both the train and validation DataLoaders. For our dataset size, the training speed is still acceptable, and the error messages disappear.

# %% [markdown]
# ### Baseline U-Net (ResNet34 encoder) – Training analysis (corrected)
#
# Using a U-Net with a **ResNet34 encoder trained from scratch** with **BCE + Dice loss**, the model improves steadily, with a strong jump in Dice during the first half of training and a stable plateau afterward.
#
# - **Epochs 1–5:** Validation Dice increases from 0.2239 → 0.5788, showing that the model quickly learns to localize tumor regions.
# - **Epochs 6–10:** Validation Dice continues to improve overall (0.6279 at epoch 6, 0.6562 at epoch 9), while Train Dice rises from 0.5817 → 0.6552. There is some fluctuation (e.g., epoch 7), which is common in segmentation.
# - **Best checkpoint:** The best validation Dice is 0.6843, first reached at epoch 13 (and matched again at epoch 15). Train/Val Dice remain very close at the end (0.6851 vs 0.6843), suggesting good generalization and limited overfitting.
# - **Late epochs (11–15):** Validation Dice stays in a narrow range (~0.64–0.68), indicating the model has largely converged.
#
# We save the model based on the best validation Dice, so with a strict “>`” condition, the saved baseline checkpoint corresponds to epoch 13 (since epoch 15 matches the best score but does not exceed it).

# %% [markdown]
# ###***Save the best results*** OK

# %%
best_model = smp.Unet(
    encoder_name="resnet34",
    encoder_weights=None,
    in_channels=3,
    classes=1,
).to(device)

best_model.load_state_dict(torch.load("unet_baseline_best.pth", map_location=device))
best_model.eval()
# Out:
# Unet(
#   (encoder): ResNetEncoder(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %% [markdown]
# ###***Visualization*** OK

# %%
import random
import matplotlib.pyplot as plt
import numpy as np
import torch.nn.functional as F

# Make sure we use the validation dataset already created: val_ds
# and the loaded best_model and device

def show_predictions(model, dataset, n_samples=3):
    model.eval()
    indices = random.sample(range(len(dataset)), k=n_samples)

    for idx in indices:
        image, mask = dataset[idx]            # image: 3xHxW, mask: 1xHxW
        img_np = image.numpy().transpose(1, 2, 0)  # HxWx3
        gt_mask = mask.numpy().squeeze()          # HxW

        with torch.no_grad():
            img_tensor = image.unsqueeze(0).to(device)  # 1x3xHxW
            logits = model(img_tensor)                  # 1x1xHxW
            probs = torch.sigmoid(logits)
            pred_mask = (probs > 0.5).float()

        pred_mask_np = pred_mask.cpu().numpy().squeeze()  # HxW

        fig, axes = plt.subplots(1, 3, figsize=(12, 4))

        # Original image (undo simple normalization approximately)
        axes[0].imshow((img_np * 0.5 + 0.5).clip(0, 1))
        axes[0].set_title("Input image")
        axes[0].axis("off")

        axes[1].imshow(gt_mask, cmap="gray")
        axes[1].set_title("Ground truth mask")
        axes[1].axis("off")

        axes[2].imshow(pred_mask_np, cmap="gray")
        axes[2].set_title("Predicted mask")
        axes[2].axis("off")

        plt.tight_layout()
        plt.show()

# Call the function to display some examples
show_predictions(best_model, val_ds, n_samples=3)

# %% [markdown]
# The visualization shows one example from the validation set.
# The ground truth mask contains a small tumor region in the center, and the predicted mask also detects a compact region in a similar location.
# After fixing the double normalization issue in our Dataset, the input image now appears as a normal MRI slice instead of a flat grey image.
# This confirms that the U-Net baseline is able to localize the tumor, even if the exact shape is not always perfectly matched.

# %% [markdown]
# #`2. Pretrained Model `

# %% [markdown]
# ## Step 2 – U-Net with a pre-trained backbone (transfer learning)
#
# In this part, we keep the same dataset and the same loss functions as in the baseline.
# The main change is the model architecture: we now use a U-Net with a ResNet34 encoder that is pre-trained on ImageNet.
#
# The idea of transfer learning is to reuse low-level and mid-level visual features that were already learned on a large and general dataset.
# Instead of starting from random weights, the network starts from weights that already know how to detect basic shapes, edges and textures.
# We then fine-tune this network on our medical images and we check if the convergence is faster and if the Dice score on the validation set is better than the baseline model trained from scratch.

# %% [markdown]
# ##**Pretrained U-Net with Optimizer** OK

# %%
import segmentation_models_pytorch as smp
import torch.optim as optim

# U-Net with a pre-trained ResNet34 encoder (transfer learning)
model_tl = smp.Unet(
    encoder_name="resnet34",
    encoder_weights="imagenet",   # pre-trained on ImageNet
    in_channels=3,
    classes=1,
).to(device)

# New optimizer for this model (smaller learning rate for fine-tuning)
EPOCHS_TL = 15
lr_tl = 1e-4
optimizer_tl = optim.Adam(model_tl.parameters(), lr=lr_tl)

print("Model with pre-trained encoder ready.")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/156 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/87.3M [00:00<?, ?B/s]
# Model with pre-trained encoder ready.

# %% [markdown]
# In this cell, we define a second U-Net model that uses transfer learning.
# The encoder of this U-Net is a ResNet34 network with weights pre-trained on the ImageNet dataset.
# The decoder part of the U-Net is initialized randomly and will be trained on our brain tumor data.
#
# We move this model to the selected device (GPU or CPU) and we create a new Adam optimizer with a smaller learning rate.
# A smaller learning rate is common in fine-tuning, because we do not want to destroy the useful pre-trained features too quickly.
# This model will be trained with the same loss functions and the same training procedure as the baseline model.

# %%
best_val_dice_tl = 0.0
tl_history = {
    "train_loss": [],
    "val_loss": [],
    "train_dice": [],
    "val_dice": [],
}

best_val_dice_tl = 0.0

for epoch in range(1, EPOCHS_TL + 1):
    print(f"\n[Transfer learning] Epoch {epoch}/{EPOCHS_TL}")

    train_loss, train_dice = train_one_epoch(model_tl, train_loader, optimizer_tl, device)
    val_loss, val_dice = evaluate(model_tl, val_loader, device)

    print(f"Train loss: {train_loss:.4f}  |  Train Dice: {train_dice:.4f}")
    print(f"Val   loss: {val_loss:.4f}  |  Val   Dice: {val_dice:.4f}")

    # 🔹 Log de l'historique complet
    tl_history["train_loss"].append(train_loss)
    tl_history["val_loss"].append(val_loss)
    tl_history["train_dice"].append(train_dice)
    tl_history["val_dice"].append(val_dice)

    if val_dice > best_val_dice_tl:
        best_val_dice_tl = val_dice
        torch.save(model_tl.state_dict(), "unet_resnet34_pretrained_best.pth")
        print("  --> New best transfer-learning model saved.")
# Out:
# [Transfer learning] Epoch 1/15
# ...
# Val:   0%|          | 0/54 [00:00<?, ?it/s]
# Train loss: 1.0972  |  Train Dice: 0.3691
# Val   loss: 0.7229  |  Val   Dice: 0.5506
#   --> New best transfer-learning model saved.
#
# [Transfer learning] Epoch 2/15
# ...
# Val:   0%|          | 0/54 [00:00<?, ?it/s]
# Train loss: 0.6117  |  Train Dice: 0.6043
# Val   loss: 0.5119  |  Val   Dice: 0.6509
#   --> New best transfer-learning model saved.
#
# [Transfer learning] Epoch 3/15
# ...
# Val:   0%|          | 0/54 [00:00<?, ?it/s]
# Train loss: 0.4666  |  Train Dice: 0.6699
# Val   loss: 0.4773  |  Val   Dice: 0.6411
#
# [Transfer learning] Epoch 4/15
# ...
# Val:   0%|          | 0/54 [00:00<?, ?it/s]
# Train loss: 0.4178  |  Train Dice: 0.6838
# Val   loss: 0.4285  |  Val   Dice: 0.6611
#   --> New best transfer-learning model saved.
#
# [Transfer learning] Epoch 5/15
# ...
# Val:   0%|          | 0/54 [00:00<?, ?it/s]
# Train loss: 0.3676  |  Train Dice: 0.7110
# Val   loss: 0.3740  |  Val   Dice: 0.7000
# ...

# %% [markdown]
# ### Results – U-Net with a pre-trained ResNet34 encoder
#
# The U-Net with a pre-trained ResNet34 encoder converges faster and reaches a higher validation Dice than the baseline model trained from scratch.
#
# From the first epochs, the transfer learning model improves quickly: Val Dice goes from 0.5506 (epoch 1) to 0.7000 (epoch 5), while the baseline is still at 0.5788 at epoch 5. This shows that pretraining helps the model learn meaningful features earlier.
#
# During training, validation Dice stays in a strong range, mostly between ~0.70 and ~0.77, with a few small drops (e.g., epoch 9 and epoch 15). The best checkpoint is obtained at epoch 14 with Val Dice = 0.7655 (Train Dice = 0.7907). The train/val gap remains moderate, suggesting decent generalization.
#
# Compared to the baseline, which reaches a best Val Dice of 0.6843 (epoch 13/15), transfer learning improves the best validation Dice by about +0.081, and also reaches good performance in fewer epochs.

# %% [markdown]
# ### ***Vizualisation***

# %%
import segmentation_models_pytorch as smp

# Charger le meilleur modèle pré-entraîné
best_model_tl = smp.Unet(
    encoder_name="resnet34",
    encoder_weights=None,   # on met None car on va charger nos propres poids
    in_channels=3,
    classes=1,
).to(device)

state_dict_tl = torch.load("unet_resnet34_pretrained_best.pth",
                           map_location=device)
best_model_tl.load_state_dict(state_dict_tl)
best_model_tl.eval()
# Out:
# Unet(
#   (encoder): ResNetEncoder(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
def show_predictions(model, dataset, n_samples=3):
    model.eval()
    indices = random.sample(range(len(dataset)), k=n_samples)

    for idx in indices:
        image, mask = dataset[idx]              # image: 3xHxW, mask: 1xHxW
        img_np = image.numpy().transpose(1, 2, 0)  # HxWx3
        gt_mask = mask.numpy().squeeze()          # HxW

        with torch.no_grad():
            img_tensor = image.unsqueeze(0).to(device)  # 1x3xHxW
            logits = model(img_tensor)                  # 1x1xHxW
            probs = torch.sigmoid(logits)
            pred_mask = (probs > 0.5).float()

        pred_mask_np = pred_mask.cpu().numpy().squeeze()  # HxW

        fig, axes = plt.subplots(1, 3, figsize=(12, 4))

        img_vis = (img_np * 0.5 + 0.5).clip(0, 1)
        axes[0].imshow(img_vis)
        axes[0].set_title("Input image")
        axes[0].axis("off")

        axes[1].imshow(gt_mask, cmap="gray")
        axes[1].set_title("Ground truth mask")
        axes[1].axis("off")

        axes[2].imshow(pred_mask_np, cmap="gray")
        axes[2].set_title("Predicted mask (TL)")
        axes[2].axis("off")

        plt.tight_layout()
        plt.show()

# Afficher quelques exemples pour le modèle pré-entraîné
show_predictions(best_model_tl, val_ds, n_samples=3)

# %% [markdown]
# #3.`Loss function comparison`

# %% [markdown]
# ## Step 3 – Comparison of different loss functions
#
# In the last part of the project, we keep the same model architecture as in Step 2, that is a U-Net with a pre-trained ResNet34 encoder.
# However, we change the loss function used for training.
#
# The baseline loss is a combination of binary cross-entropy and Dice loss.
# This already works well, but it is interesting to test other losses that are designed for imbalanced segmentation problems, where the positive class (tumor) is much smaller than the background.
#
# We focus on two popular alternatives: Focal Loss and Tversky Loss.
# Both of them try to give more weight to difficult pixels or to specific types of errors (false positives and false negatives).
# We will train the same model with each loss and compare the validation Dice scores and the visual quality of the predicted masks.

# %% [markdown]
# ### **New loss Functions** OK

# %%
import torch.nn.functional as F

def focal_loss_with_logits(logits, targets, alpha=0.25, gamma=2.0, eps=1e-7):
    """
    Binary focal loss for logits.
    logits: raw model outputs (B,1,H,W)
    targets: binary masks (B,1,H,W) in {0,1}
    """
    probs = torch.sigmoid(logits)
    probs = probs.clamp(eps, 1.0 - eps)

    pt = probs * targets + (1 - probs) * (1 - targets)  # p_t
    w = alpha * targets + (1 - alpha) * (1 - targets)   # class weighting

    loss = -w * (1 - pt) ** gamma * torch.log(pt)
    return loss.mean()


def tversky_index_with_logits(logits, targets, alpha=0.5, beta=0.5, eps=1e-7):
    """
    Tversky index for binary segmentation.
    """
    probs = torch.sigmoid(logits)
    preds = probs

    TP = (preds * targets).sum(dim=(1, 2, 3))
    FP = (preds * (1 - targets)).sum(dim=(1, 2, 3))
    FN = ((1 - preds) * targets).sum(dim=(1, 2, 3))

    tversky = (TP + eps) / (TP + alpha * FN + beta * FP + eps)
    return tversky.mean()


def tversky_loss_with_logits(logits, targets, alpha=0.5, beta=0.5, eps=1e-7):
    """
    Tversky loss = 1 - Tversky index.
    """
    return 1.0 - tversky_index_with_logits(logits, targets, alpha=alpha, beta=beta, eps=eps)

# %% [markdown]
# In this cell, we implement two alternative loss functions for binary segmentation.
# The function `focal_loss_with_logits` implements the binary Focal Loss.
# It reduces the weight of easy pixels and focuses more on difficult pixels, thanks to the gamma parameter.
# This can help when the background class is much more frequent than the tumor class.
#
# The function `tversky_loss_with_logits` is based on the Tversky index, which is a generalization of the Dice coefficient.
# It uses two parameters, alpha and beta, to control the balance between false positives and false negatives.
# The Tversky Loss is equal to one minus the Tversky index, so minimizing this loss is equivalent to maximizing the overlap between prediction and ground truth with a specific penalty on different types of errors.

# %% [markdown]
# ### Training with Focal Loss (pre-trained U-Net) OK

# %%
# New model for Focal Loss experiment
model_focal = smp.Unet(
    encoder_name="resnet34",
    encoder_weights="imagenet",
    in_channels=3,
    classes=1,
).to(device)

optimizer_focal = optim.Adam(model_focal.parameters(), lr=1e-4)
EPOCHS_FOCAL = 15
best_val_dice_focal = 0.0


focal_history = {
    "train_loss": [],
    "val_loss": [],
    "train_dice": [],
    "val_dice": [],
}

best_val_dice_focal = 0.0



for epoch in range(1, EPOCHS_FOCAL + 1):
    print(f"\n[Focal Loss] Epoch {epoch}/{EPOCHS_FOCAL}")
    model_focal.train()
    running_loss = 0.0
    running_dice = 0.0

    for images, masks in train_loader:
        images = images.to(device)
        masks = masks.to(device)

        optimizer_focal.zero_grad()
        outputs = model_focal(images)

        loss = focal_loss_with_logits(outputs, masks)
        dice = dice_coeff(outputs, masks)

        loss.backward()
        optimizer_focal.step()

        running_loss += loss.item() * images.size(0)
        running_dice += dice.item() * images.size(0)

    train_loss = running_loss / len(train_loader.dataset)
    train_dice = running_dice / len(train_loader.dataset)

    # Validation
    model_focal.eval()
    val_running_loss = 0.0
    val_running_dice = 0.0

    with torch.no_grad():
        for images, masks in val_loader:
            images = images.to(device)
            masks = masks.to(device)

            outputs = model_focal(images)
            loss = focal_loss_with_logits(outputs, masks)
            dice = dice_coeff(outputs, masks)

            val_running_loss += loss.item() * images.size(0)
            val_running_dice += dice.item() * images.size(0)

    val_loss = val_running_loss / len(val_loader.dataset)
    val_dice = val_running_dice / len(val_loader.dataset)

    print(f"Train loss: {train_loss:.4f}  |  Train Dice: {train_dice:.4f}")
    print(f"Val   loss: {val_loss:.4f}  |  Val   Dice: {val_dice:.4f}")

    # 🔹 Log complet pour les courbes
    focal_history["train_loss"].append(train_loss)
    focal_history["val_loss"].append(val_loss)
    focal_history["train_dice"].append(train_dice)
    focal_history["val_dice"].append(val_dice)

    if val_dice > best_val_dice_focal:
        best_val_dice_focal = val_dice
        torch.save(model_focal.state_dict(), "unet_resnet34_focal_best.pth")
        print("  --> New best Focal Loss model saved.")
# Out:
# [Focal Loss] Epoch 1/15
# Train loss: 0.0261  |  Train Dice: 0.0226
# Val   loss: 0.0118  |  Val   Dice: 0.0698
#   --> New best Focal Loss model saved.
#
# [Focal Loss] Epoch 2/15
# Train loss: 0.0097  |  Train Dice: 0.2774
# Val   loss: 0.0077  |  Val   Dice: 0.3631
#   --> New best Focal Loss model saved.
#
# [Focal Loss] Epoch 3/15
# Train loss: 0.0069  |  Train Dice: 0.4974
# Val   loss: 0.0059  |  Val   Dice: 0.5567
#   --> New best Focal Loss model saved.
#
# [Focal Loss] Epoch 4/15
# Train loss: 0.0058  |  Train Dice: 0.5561
# Val   loss: 0.0054  |  Val   Dice: 0.6796
#   --> New best Focal Loss model saved.
#
# [Focal Loss] Epoch 5/15
# Train loss: 0.0052  |  Train Dice: 0.6089
# Val   loss: 0.0055  |  Val   Dice: 0.5127
#
# [Focal Loss] Epoch 6/15
# Train loss: 0.0049  |  Train Dice: 0.6281
# Val   loss: 0.0051  |  Val   Dice: 0.5828
#
# [Focal Loss] Epoch 7/15
# Train loss: 0.0045  |  Train Dice: 0.6579
# Val   loss: 0.0048  |  Val   Dice: 0.6194
#
# ...

# %% [markdown]
# In this experiment, we keep the same pre-trained U-Net with ResNet34 encoder,
# but we replace the BCE + Dice loss with the Focal Loss.
# The goal is to see if Focal Loss can further improve the segmentation of small tumor regions
# by giving more weight to hard pixels and rare positive examples.

# %% [markdown]
# ### Results – U-Net with Focal Loss
#
# In this experiment, we keep the same pre-trained U-Net setup and train it using Focal Loss.
#
# At the beginning, Dice scores are extremely low (Train Dice = 0.0226, Val Dice = 0.0698 at epoch 1). This slow start is expected with Focal Loss, since it down-weights easy pixels and focuses more on hard/rare tumor pixels.
#
# From epochs 2 to 4, performance improves very quickly: validation Dice increases from 0.3631 (epoch 2) to 0.6796 (epoch 4). After that, the validation Dice becomes more unstable, with noticeable fluctuations (for example 0.5127 at epoch 5, then 0.7292 at epoch 8).
#
# The best checkpoint is obtained at epoch 15 with Val Dice = 0.7410 (Train Dice = 0.7197). Overall, Focal Loss reaches a solid final score, but its validation curve is less stable than the BCE+Dice transfer learning run, and it remains slightly below the best transfer learning result (0.7655).

# %% [markdown]
# ### Training with Tversky Loss (pre-trained U-Net) OK

# %%
# New model for Tversky Loss experiment
model_tversky = smp.Unet(
    encoder_name="resnet34",
    encoder_weights="imagenet",
    in_channels=3,
    classes=1,
).to(device)

optimizer_tversky = optim.Adam(model_tversky.parameters(), lr=1e-4)
EPOCHS_TVERSKY = 15
best_val_dice_tversky = 0.0


tversky_history = {
    "train_loss": [],
    "val_loss": [],
    "train_dice": [],
    "val_dice": [],
}

best_val_dice_tversky = 0.0


for epoch in range(1, EPOCHS_TVERSKY + 1):
    print(f"\n[Tversky Loss] Epoch {epoch}/{EPOCHS_TVERSKY}")
    model_tversky.train()
    running_loss = 0.0
    running_dice = 0.0

    for images, masks in train_loader:
        images = images.to(device)
        masks = masks.to(device)

        optimizer_tversky.zero_grad()
        outputs = model_tversky(images)

        loss = tversky_loss_with_logits(outputs, masks, alpha=0.5, beta=0.5)
        dice = dice_coeff(outputs, masks)

        loss.backward()
        optimizer_tversky.step()

        running_loss += loss.item() * images.size(0)
        running_dice += dice.item() * images.size(0)

    train_loss = running_loss / len(train_loader.dataset)
    train_dice = running_dice / len(train_loader.dataset)

    # Validation
    model_tversky.eval()
    val_running_loss = 0.0
    val_running_dice = 0.0

    with torch.no_grad():
        for images, masks in val_loader:
            images = images.to(device)
            masks = masks.to(device)

            outputs = model_tversky(images)
            loss = tversky_loss_with_logits(outputs, masks, alpha=0.5, beta=0.5)
            dice = dice_coeff(outputs, masks)

            val_running_loss += loss.item() * images.size(0)
            val_running_dice += dice.item() * images.size(0)

    val_loss = val_running_loss / len(val_loader.dataset)
    val_dice = val_running_dice / len(val_loader.dataset)

    print(f"Train loss: {train_loss:.4f}  |  Train Dice: {train_dice:.4f}")
    print(f"Val   loss: {val_loss:.4f}  |  Val   Dice: {val_dice:.4f}")

    # 🔹 Log complet
    tversky_history["train_loss"].append(train_loss)
    tversky_history["val_loss"].append(val_loss)
    tversky_history["train_dice"].append(train_dice)
    tversky_history["val_dice"].append(val_dice)

    if val_dice > best_val_dice_tversky:
        best_val_dice_tversky = val_dice
        torch.save(model_tversky.state_dict(), "unet_resnet34_tversky_best.pth")
        print("  --> New best Tversky Loss model saved.")
# Out:
# [Tversky Loss] Epoch 1/15
# Train loss: 0.8467  |  Train Dice: 0.2791
# Val   loss: 0.7837  |  Val   Dice: 0.3893
#   --> New best Tversky Loss model saved.
#
# [Tversky Loss] Epoch 2/15
# Train loss: 0.7215  |  Train Dice: 0.4447
# Val   loss: 0.6353  |  Val   Dice: 0.4941
#   --> New best Tversky Loss model saved.
#
# [Tversky Loss] Epoch 3/15
# Train loss: 0.6108  |  Train Dice: 0.5298
# Val   loss: 0.5414  |  Val   Dice: 0.5910
#   --> New best Tversky Loss model saved.
#
# [Tversky Loss] Epoch 4/15
# Train loss: 0.5213  |  Train Dice: 0.5956
# Val   loss: 0.4835  |  Val   Dice: 0.6220
#   --> New best Tversky Loss model saved.
#
# [Tversky Loss] Epoch 5/15
# Train loss: 0.4373  |  Train Dice: 0.6547
# Val   loss: 0.4080  |  Val   Dice: 0.6901
#   --> New best Tversky Loss model saved.
#
# [Tversky Loss] Epoch 6/15
# Train loss: 0.3670  |  Train Dice: 0.7007
# Val   loss: 0.3423  |  Val   Dice: 0.7126
#   --> New best Tversky Loss model saved.
#
# [Tversky Loss] Epoch 7/15
# ...

# %% [markdown]
# we keep the same pre-trained U-Net with ResNet34 encoder,
# but we train it with the Tversky Loss instead of BCE + Dice or Focal Loss.
# The Tversky Loss is designed for imbalanced segmentation and lets us choose how much
# to penalize false positives and false negatives through the alpha and beta parameters.
# We train the model on the same train and validation splits and then compare the validation Dice
# with the previous loss functions.

# %% [markdown]
# ### Results – U-Net with Tversky Loss
#
# In this experiment, we train the same pre-trained U-Net with a ResNet34 encoder, but we use Tversky Loss.
#
# Training starts with moderate Dice scores (Train Dice = 0.2791, Val Dice = 0.3893 at epoch 1) and improves steadily. By epoch 5, validation Dice already reaches 0.6901, and it keeps increasing with only small fluctuations.
#
# From epochs 6 to 15, the model stays in a strong range, with validation Dice mostly between ~0.71 and ~0.77. The best checkpoint is obtained at epoch 13 with Val Dice = 0.7664 (Train Dice = 0.7660). The train/val gap remains very small near the end, which suggests good generalization and no clear overfitting in this run.
#
# ### Comparison with other configurations (best validation Dice)
#
# - Baseline (from scratch): 0.6843 → Tversky is higher by about +0.082.
# - Transfer learning with BCE + Dice: 0.7655 → Tversky is extremely close (difference ≈ +0.001 in favor of Tversky).
# - Focal Loss: 0.7410 → Tversky is higher by about +0.025.
#
# Overall, Tversky Loss gives one of the best results in our experiments and performs very close to the best BCE+Dice transfer learning run, while being more stable than the Focal Loss training.

# %% [markdown]
# # Overall comparison of models and loss functions
#
# In this project, we tested several configurations for brain tumor segmentation using U-Net models.
#
# First, the baseline U-Net (ResNet34 encoder, trained from scratch with BCE + Dice) reaches a best validation Dice of **0.6843** (epoch 13, matched at epoch 15).
# Then, using transfer learning (pre-trained ResNet34 encoder) with the same BCE + Dice loss improves the best validation Dice to **0.7655** (epoch 14). This shows a clear benefit of transfer learning on our dataset, both in convergence speed and final performance.
#
# When we keep the same pre-trained U-Net and change only the loss function, Focal Loss reaches a best validation Dice of **0.7410** (epoch 15), and Tversky Loss reaches **0.7664** (epoch 13).
# Focal Loss performs well but shows stronger fluctuations across epochs. Tversky Loss is very stable and achieves the highest validation Dice among all tested settings, although the difference with BCE + Dice (transfer learning) is very small.
#
# Overall, the best configuration in our experiments is the pre-trained U-Net trained with **Tversky Loss** (Val Dice = **0.7664**), followed extremely closely by transfer learning with **BCE + Dice** (Val Dice = **0.7655**). Both provide strong segmentation quality and good generalization.

# %% [markdown]
# # Curves

# %% [markdown]
# ##Dice Curves – Baseline vs Transfer Learning

# %%
import matplotlib.pyplot as plt

epochs_baseline = range(1, len(baseline_history["train_dice"]) + 1)
epochs_tl = range(1, len(tl_history["train_dice"]) + 1)

plt.figure(figsize=(8, 5))

plt.plot(epochs_baseline, baseline_history["train_dice"], label="Baseline Train Dice")
plt.plot(epochs_baseline, baseline_history["val_dice"],   label="Baseline Val Dice")

plt.plot(epochs_tl, tl_history["train_dice"], label="TL Train Dice")
plt.plot(epochs_tl, tl_history["val_dice"],   label="TL Val Dice")

plt.xlabel("Epoch")
plt.ylabel("Dice")
plt.title("Dice curves – Baseline vs Transfer Learning")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Figure 1 – Dice curves: Baseline vs Transfer Learning
#
# This figure compares the training and validation Dice scores for the baseline U-Net and for the U-Net with a pre-trained ResNet34 encoder.
# The baseline model starts with a lower Dice and improves slowly during training. Its validation Dice stays around 0.70–0.74 and the gap between train and validation is sometimes quite large, which suggests a limited capacity and a bit of overfitting.
# The transfer learning model starts with a much higher Dice score, close to 0.80 from the first epochs, and remains stable around 0.78–0.83 on both train and validation. The curves of train and validation Dice are close to each other, which indicates good generalization. This figure clearly shows the benefit of using a pre-trained encoder for this segmentation task.

# %% [markdown]
# ##Loss Curves – Baseline vs Transfer Learning

# %%
epochs_baseline = range(1, len(baseline_history["train_loss"]) + 1)
epochs_tl = range(1, len(tl_history["train_loss"]) + 1)

plt.figure(figsize=(8, 5))

plt.plot(epochs_baseline, baseline_history["train_loss"], label="Baseline Train Loss")
plt.plot(epochs_baseline, baseline_history["val_loss"],   label="Baseline Val Loss")

plt.plot(epochs_tl, tl_history["train_loss"], label="TL Train Loss")
plt.plot(epochs_tl, tl_history["val_loss"],   label="TL Val Loss")

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss curves – Baseline vs Transfer Learning")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Figure 2 – Loss curves: Baseline vs Transfer Learning
#
# This figure shows the evolution of the training and validation loss for the baseline U-Net and for the pre-trained U-Net.
# The baseline model starts with a relatively high loss and decreases slowly. The validation loss follows the same trend but remains higher than the training loss, especially in the middle of training, which again suggests some overfitting and a less efficient optimization.
# For the transfer learning model, both training and validation losses are lower overall and more stable. The validation loss closely follows the training loss during all epochs. This behaviour confirms that the pre-trained model learns faster and reaches a better optimum than the baseline model trained from scratch.

# %% [markdown]
# ##Val Dice Curves – different losses

# %%
epochs_tl      = range(1, len(tl_history["val_dice"]) + 1)
epochs_focal   = range(1, len(focal_history["val_dice"]) + 1)
epochs_tversky = range(1, len(tversky_history["val_dice"]) + 1)

plt.figure(figsize=(8, 5))

plt.plot(epochs_tl,      tl_history["val_dice"],      label="BCE + Dice (TL)")
plt.plot(epochs_focal,   focal_history["val_dice"],   label="Focal Loss (TL)")
plt.plot(epochs_tversky, tversky_history["val_dice"], label="Tversky Loss (TL)")

plt.xlabel("Epoch")
plt.ylabel("Validation Dice")
plt.title("Validation Dice – Different loss functions (same pre-trained model)")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Figure 3 – Validation Dice for different loss functions (same pre-trained model)
#
# In this figure, all curves correspond to the same pre-trained U-Net with a ResNet34 encoder, but each curve uses a different loss function.
# The BCE + Dice loss reaches the highest validation Dice, around 0.78–0.80, and remains stable after a few epochs. The Tversky loss also gives good performance, with a validation Dice around 0.74–0.76, but it stays slightly below the BCE + Dice curve. The Focal Loss starts with very low Dice values and improves during training, but it saturates around 0.60–0.65, which is clearly lower than the two other losses.
# This figure shows that, for this dataset and model, the BCE + Dice loss is the most effective choice, Tversky loss is a reasonable alternative, and Focal Loss is less adapted with the current hyperparameters.

# %% [markdown]
# ##Barplot of the best Val Dice by configuration

# %%
import numpy as np
import matplotlib.pyplot as plt

configs = [
    "Baseline\nResNet18\nBCE+Dice",
    "TL ResNet34\nBCE+Dice",
    "TL ResNet34\nFocal",
    "TL ResNet34\nTversky",
]

best_val_dice = [
    max(baseline_history["val_dice"]),   # ≈ 0.68
    max(tl_history["val_dice"]),         # ≈ 0.79
    max(focal_history["val_dice"]),      # ≈ 0.71
    max(tversky_history["val_dice"]),    # ≈ 0.75
]

x = np.arange(len(configs))

plt.figure(figsize=(8, 5))
plt.bar(x, best_val_dice)
plt.xticks(x, configs, rotation=20, ha="right")
plt.ylabel("Best validation Dice")
plt.title("Best validation Dice for each configuration")
plt.ylim(0, 1.0)
plt.grid(axis="y")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Figure 4 – Best validation Dice for each configuration
#
# This bar chart summarizes the best validation Dice obtained with each model and loss configuration.
# The baseline U-Net with a ResNet18 encoder trained from scratch reaches a best validation Dice of about 0.70. When we switch to a pre-trained ResNet34 encoder and keep the BCE + Dice loss, the best validation Dice increases to around 0.79, which is the highest score among all experiments. Using the same pre-trained model with Focal Loss gives a lower best Dice, around 0.60, while Tversky Loss reaches an intermediate value around 0.75.
# This figure confirms two main conclusions of the project: transfer learning with a pre-trained encoder brings a large improvement compared to the baseline model, and among the tested loss functions, the BCE + Dice loss provides the best overall performance on this brain tumor segmentation task.

# %% [markdown]
# # Figures used for the oral

# %%
import random
import matplotlib.pyplot as plt
import numpy as np

def show_input_and_gt(dataset, n_samples=3, seed=0):
    random.seed(seed)
    indices = random.sample(range(len(dataset)), k=n_samples)

    for idx in indices:
        image, mask = dataset[idx]  # image: 3xHxW, mask: 1xHxW (your dataset) :contentReference[oaicite:1]{index=1}
        img_np = image.numpy().transpose(1, 2, 0)      # HxWx3
        gt_mask = mask.numpy().squeeze()               # HxW

        # (Optional) undo your normalization approximately (you do it already elsewhere) :contentReference[oaicite:2]{index=2}
        img_vis = (img_np * 0.5 + 0.5).clip(0, 1)

        tumor_ratio = gt_mask.mean() * 100  # since mask is 0/1

        fig, axes = plt.subplots(1, 2, figsize=(8, 4))
        axes[0].imshow(img_vis)
        axes[0].set_title("Input MRI")
        axes[0].axis("off")

        axes[1].imshow(gt_mask, cmap="gray")
        axes[1].set_title(f"Ground Truth Mask\nTumor pixels: {tumor_ratio:.2f}%")
        axes[1].axis("off")

        plt.tight_layout()
        plt.show()

# Example: show 3 validation samples
show_input_and_gt(val_ds, n_samples=3)

# %%
import numpy as np
import matplotlib.pyplot as plt

def show_sample(dataset, idx):
    image, mask = dataset[idx]  # image: CxHxW, mask: 1xHxW

    img = image.detach().cpu().float().numpy()
    msk = mask.detach().cpu().float().numpy().squeeze()  # HxW

    # --- 1) Denormalize (if you used mean=0.5 std=0.5) ---
    # If your visualization is already correct, keep it; otherwise this is usually needed.
    img = img * 0.5 + 0.5
    img = np.clip(img, 0, 1)

    # --- 2) Convert to grayscale for MRI display ---
    # If RGB, take channel 0 (they are usually identical or close)
    if img.shape[0] == 3:
        img_gray = img[0]
    else:
        img_gray = img.squeeze()

    # --- 3) Contrast stretching (super important for MRI) ---
    vmin, vmax = np.percentile(img_gray, (1, 99))
    img_gray_cs = np.clip((img_gray - vmin) / (vmax - vmin + 1e-8), 0, 1)

    # --- 4) Create an overlay (mask in red) ---
    overlay = np.dstack([img_gray_cs, img_gray_cs, img_gray_cs])
    overlay[msk > 0, 0] = 1.0  # Red channel
    overlay[msk > 0, 1] = 0.0
    overlay[msk > 0, 2] = 0.0

    tumor_ratio = msk.mean() * 100

    fig, axes = plt.subplots(1, 3, figsize=(12, 4))
    axes[0].imshow(img_gray_cs, cmap="gray")
    axes[0].set_title("Input MRI (contrast-stretched)")
    axes[0].axis("off")

    axes[1].imshow(msk, cmap="gray")
    axes[1].set_title(f"Ground Truth Mask\nTumor pixels: {tumor_ratio:.2f}%")
    axes[1].axis("off")

    axes[2].imshow(overlay)
    axes[2].set_title("Overlay (tumor in red)")
    axes[2].axis("off")

    plt.tight_layout()
    plt.show()

# Example usage:
show_sample(val_ds, idx=0)

# %%
import numpy as np
import matplotlib.pyplot as plt

def tumor_pixel_ratios(dataset, max_items=None):
    n = len(dataset) if max_items is None else min(len(dataset), max_items)
    ratios = []
    for i in range(n):
        _, mask = dataset[i]
        gt_mask = mask.numpy().squeeze()
        ratios.append(gt_mask.mean())  # fraction of pixels that are tumor
    return np.array(ratios)

ratios = tumor_pixel_ratios(val_ds)  # or train_ds (takes longer)

plt.figure(figsize=(7,4))
plt.hist(ratios * 100, bins=30)
plt.xlabel("Tumor pixel ratio (%)")
plt.ylabel("Number of images")
plt.title("Tumor area is small (pixel-level class imbalance)")
plt.grid(True)
plt.tight_layout()
plt.show()

print("Median tumor ratio (%):", np.median(ratios)*100)
print("Mean tumor ratio (%):", np.mean(ratios)*100)
print("90th percentile (%):", np.percentile(ratios, 90)*100)
# Out:
# Median tumor ratio (%): 3.0654907
# Mean tumor ratio (%): 3.7312682
# 90th percentile (%): 7.4896226

# %%
# pick indices at different quantiles
q10 = int(np.argmin(np.abs(ratios - np.percentile(ratios, 10))))
q50 = int(np.argmin(np.abs(ratios - np.percentile(ratios, 50))))
q90 = int(np.argmin(np.abs(ratios - np.percentile(ratios, 90))))

for idx in [q10, q50, q90]:
    image, mask = val_ds[idx]
    img_np = image.numpy().transpose(1,2,0)
    gt_mask = mask.numpy().squeeze()
    img_vis = (img_np * 0.5 + 0.5).clip(0, 1)
    tumor_ratio = gt_mask.mean() * 100

    fig, axes = plt.subplots(1, 2, figsize=(8, 4))
    axes[0].imshow(img_vis); axes[0].set_title("Input MRI"); axes[0].axis("off")
    axes[1].imshow(gt_mask, cmap="gray")
    axes[1].set_title(f"GT Mask ({tumor_ratio:.2f}% tumor)")
    axes[1].axis("off")
    plt.tight_layout()
    plt.show()

# %%
import json
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from PIL import Image, ImageDraw

def resolve_img_path(split_dir: Path, file_name: str) -> Path:
    fn = Path(file_name)

    candidates = [
        split_dir / fn,                      # same logic as your dataset :contentReference[oaicite:1]{index=1}
        split_dir / fn.name,                 # if COCO stores "images/x.jpg"
        split_dir / "images" / fn,           # if there is a real images/ folder
        split_dir / "images" / fn.name,
    ]
    for p in candidates:
        if p.exists():
            return p

    raise FileNotFoundError(
        f"Could not find image file for file_name='{file_name}'. Tried:\n" +
        "\n".join([str(p) for p in candidates])
    )

def coco_demo_figure(split_dir: Path, sample_idx: int = 0):
    ann_path = split_dir / "_annotations.coco.json"
    with open(ann_path, "r") as f:
        coco = json.load(f)

    images = coco["images"]
    anns = coco["annotations"]

    img_info = images[sample_idx]
    img_id = img_info["id"]
    file_name = img_info["file_name"]

    img_path = resolve_img_path(split_dir, file_name)
    img_pil = Image.open(img_path).convert("RGB")
    W, H = img_pil.size

    img_anns = [a for a in anns if a["image_id"] == img_id]

    overlay = img_pil.copy()
    draw = ImageDraw.Draw(overlay)

    mask_pil = Image.new("L", (W, H), 0)
    mask_draw = ImageDraw.Draw(mask_pil)

    for a in img_anns:
        segs = a.get("segmentation", [])
        for poly in segs:
            pts = [(poly[i], poly[i+1]) for i in range(0, len(poly), 2)]
            draw.line(pts + [pts[0]], fill=(255, 0, 0), width=3)
            mask_draw.polygon(pts, outline=1, fill=1)

    mask = np.array(mask_pil, dtype=np.uint8)
    tumor_ratio = mask.mean() * 100

    fig, axes = plt.subplots(1, 3, figsize=(12, 4))
    axes[0].imshow(img_pil);   axes[0].set_title("Input MRI"); axes[0].axis("off")
    axes[1].imshow(overlay);   axes[1].set_title("COCO polygon overlay"); axes[1].axis("off")
    axes[2].imshow(mask, cmap="gray")
    axes[2].set_title(f"Binary mask (tumor=1)\nTumor pixels: {tumor_ratio:.2f}%")
    axes[2].axis("off")
    plt.tight_layout()
    plt.show()

# Run (same dirs as your notebook) :contentReference[oaicite:2]{index=2}
coco_demo_figure(TRAIN_DIR, sample_idx=0)

# %%
import json
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from PIL import Image, ImageDraw

def resolve_img_path(split_dir: Path, file_name: str) -> Path:
    fn = Path(file_name)
    candidates = [
        split_dir / fn,          # file_name may already include subfolders
        split_dir / fn.name,     # keep only basename
        split_dir / "images" / fn,
        split_dir / "images" / fn.name,
    ]
    for p in candidates:
        if p.exists():
            return p
    raise FileNotFoundError(f"Image not found for '{file_name}'. Tried:\n" + "\n".join(map(str, candidates)))

def make_coco_mask_figure(split_dir: Path, sample_idx: int = 0):
    ann_path = split_dir / "_annotations.coco.json"
    coco = json.loads(Path(ann_path).read_text())

    img_info = coco["images"][sample_idx]
    img_id = img_info["id"]
    file_name = img_info["file_name"]

    img_path = resolve_img_path(split_dir, file_name)
    img = Image.open(img_path).convert("RGB")
    W, H = img.size

    anns = [a for a in coco["annotations"] if a["image_id"] == img_id]

    overlay = img.copy()
    draw = ImageDraw.Draw(overlay)

    mask_img = Image.new("L", (W, H), 0)
    mask_draw = ImageDraw.Draw(mask_img)

    for a in anns:
        for poly in a.get("segmentation", []):
            pts = [(poly[i], poly[i+1]) for i in range(0, len(poly), 2)]
            draw.line(pts + [pts[0]], fill=(255, 0, 0), width=3)
            mask_draw.polygon(pts, outline=1, fill=1)

    mask = np.array(mask_img, dtype=np.uint8)
    tumor_ratio = mask.mean() * 100

    fig, ax = plt.subplots(1, 3, figsize=(12, 4))
    ax[0].imshow(img);     ax[0].set_title("Input MRI"); ax[0].axis("off")
    ax[1].imshow(overlay); ax[1].set_title("COCO polygon annotation (overlay)"); ax[1].axis("off")
    ax[2].imshow(mask, cmap="gray")
    ax[2].set_title(f"Binary mask (tumor=1)\nTumor pixels: {tumor_ratio:.2f}%")
    ax[2].axis("off")
    plt.tight_layout()
    plt.show()

# Use your existing directories:
make_coco_mask_figure(TRAIN_DIR, sample_idx=0)   # or VAL_DIR / TEST_DIR

# %%
import re
import pandas as pd
import matplotlib.pyplot as plt

baseline_log = r"""
Epoch 1/15
Train loss: 1.1961  |  Train Dice: 0.0460
Val   loss: 0.9551  |  Val   Dice: 0.2050
Epoch 2/15
Train loss: 0.8133  |  Train Dice: 0.3181
Val   loss: 0.6737  |  Val   Dice: 0.4348
Epoch 3/15
Train loss: 0.6592  |  Train Dice: 0.4427
Val   loss: 0.6207  |  Val   Dice: 0.4687
Epoch 4/15
Train loss: 0.5870  |  Train Dice: 0.5006
Val   loss: 0.5096  |  Val   Dice: 0.5669
Epoch 5/15
Train loss: 0.5377  |  Train Dice: 0.5404
Val   loss: 0.5602  |  Val   Dice: 0.5119
Epoch 6/15
Train loss: 0.5138  |  Train Dice: 0.5575
Val   loss: 0.5228  |  Val   Dice: 0.5452
Epoch 7/15
Train loss: 0.4796  |  Train Dice: 0.5879
Val   loss: 0.4923  |  Val   Dice: 0.5790
Epoch 8/15
Train loss: 0.4690  |  Train Dice: 0.5957
Val   loss: 0.4356  |  Val   Dice: 0.6245
Epoch 9/15
Train loss: 0.4436  |  Train Dice: 0.6179
Val   loss: 0.4397  |  Val   Dice: 0.6182
Epoch 10/15
Train loss: 0.4340  |  Train Dice: 0.6256
Val   loss: 0.4310  |  Val   Dice: 0.6279
Epoch 11/15
Train loss: 0.4212  |  Train Dice: 0.6369
Val   loss: 0.4366  |  Val   Dice: 0.6188
Epoch 12/15
Train loss: 0.4058  |  Train Dice: 0.6502
Val   loss: 0.4168  |  Val   Dice: 0.6370
Epoch 13/15
Train loss: 0.3859  |  Train Dice: 0.6675
Val   loss: 0.3737  |  Val   Dice: 0.6784
Epoch 14/15
Train loss: 0.3849  |  Train Dice: 0.6682
Val   loss: 0.3580  |  Val   Dice: 0.6926
Epoch 15/15
Train loss: 0.3741  |  Train Dice: 0.6778
Val   loss: 0.3967  |  Val   Dice: 0.6538
"""

def parse_baseline_log(text: str) -> pd.DataFrame:
    epoch_re = re.compile(r"Epoch\s+(\d+)/\d+")
    train_re = re.compile(r"Train loss:\s*([0-9.]+)\s*\|\s*Train Dice:\s*([0-9.]+)")
    val_re   = re.compile(r"Val\s+loss:\s*([0-9.]+)\s*\|\s*Val\s+Dice:\s*([0-9.]+)")

    lines = [l.strip() for l in text.strip().splitlines() if l.strip()]
    rows = []
    cur_epoch = None
    cur = {}

    for l in lines:
        m = epoch_re.search(l)
        if m:
            if cur_epoch is not None and {"train_loss","train_dice","val_loss","val_dice"} <= cur.keys():
                rows.append({"epoch": cur_epoch, **cur})
            cur_epoch = int(m.group(1))
            cur = {}
            continue

        m = train_re.search(l)
        if m:
            cur["train_loss"] = float(m.group(1))
            cur["train_dice"] = float(m.group(2))
            continue

        m = val_re.search(l)
        if m:
            cur["val_loss"] = float(m.group(1))
            cur["val_dice"] = float(m.group(2))
            continue

    if cur_epoch is not None and {"train_loss","train_dice","val_loss","val_dice"} <= cur.keys():
        rows.append({"epoch": cur_epoch, **cur})

    df = pd.DataFrame(rows).sort_values("epoch").reset_index(drop=True)
    return df

df = parse_baseline_log(baseline_log)

# ---- 1) CURVE (Train/Val Dice + Val Loss) ----
best_idx = df["val_dice"].idxmax()
best_epoch = int(df.loc[best_idx, "epoch"])
best_val_dice = float(df.loc[best_idx, "val_dice"])

plt.figure(figsize=(8,4))
plt.plot(df["epoch"], df["train_dice"], marker="o", label="Train Dice")
plt.plot(df["epoch"], df["val_dice"], marker="o", label="Val Dice")
plt.xlabel("Epoch")
plt.ylabel("Dice")
plt.title(f"Baseline: Dice over epochs (best Val Dice = {best_val_dice:.4f} at epoch {best_epoch})")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

plt.figure(figsize=(8,4))
plt.plot(df["epoch"], df["val_loss"], marker="o", label="Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Baseline: Validation loss over epochs")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# ---- 2) TABLE (full + small summary) ----
print("Full table (first rows):")
display(df)

summary = df.loc[[0, 7, best_idx, len(df)-1], ["epoch","train_loss","train_dice","val_loss","val_dice"]].copy()
summary = summary.rename(index={
    0: "Epoch 1",
    7: "Epoch 8",
    best_idx: f"Best (Epoch {best_epoch})",
    len(df)-1: "Last (Epoch 15)"
})
print("\nSlide-friendly summary table:")
display(summary)
# Out:
# Full table (first rows):
#     epoch  train_loss  train_dice  val_loss  val_dice
# 0       1      1.1961      0.0460    0.9551    0.2050
# 1       2      0.8133      0.3181    0.6737    0.4348
# 2       3      0.6592      0.4427    0.6207    0.4687
# 3       4      0.5870      0.5006    0.5096    0.5669
# 4       5      0.5377      0.5404    0.5602    0.5119
# 5       6      0.5138      0.5575    0.5228    0.5452
# 6       7      0.4796      0.5879    0.4923    0.5790
# 7       8      0.4690      0.5957    0.4356    0.6245
# 8       9      0.4436      0.6179    0.4397    0.6182
# 9      10      0.4340      0.6256    0.4310    0.6279
# 10     11      0.4212      0.6369    0.4366    0.6188
# 11     12      0.4058      0.6502    0.4168    0.6370
# 12     13      0.3859      0.6675    0.3737    0.6784
# 13     14      0.3849      0.6682    0.3580    0.6926
# 14     15      0.3741      0.6778    0.3967    0.6538
# Slide-friendly summary table:
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Assumes you already have these dicts from training:
# baseline_history and tl_history (as in your main file)

def best_epoch_and_value(vals):
    vals = np.array(vals, dtype=float)
    idx = int(np.argmax(vals))
    return idx + 1, float(vals[idx])  # epoch is 1-based

# --- Extract ---
b_val = baseline_history["val_dice"]
t_val = tl_history["val_dice"]

epochs_b = np.arange(1, len(b_val) + 1)
epochs_t = np.arange(1, len(t_val) + 1)

b_best_ep, b_best = best_epoch_and_value(b_val)
t_best_ep, t_best = best_epoch_and_value(t_val)

# --- Plot: Val Dice comparison ---
plt.figure(figsize=(8,4))
plt.plot(epochs_b, b_val, marker="o", label="Baseline Val Dice")
plt.plot(epochs_t, t_val, marker="o", label="Transfer Learning Val Dice")
plt.axvline(b_best_ep, linestyle="--")
plt.axvline(t_best_ep, linestyle="--")
plt.xlabel("Epoch")
plt.ylabel("Validation Dice")
plt.title("Validation Dice: Baseline vs Transfer Learning")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Save for Canva (optional)
# plt.savefig("val_dice_baseline_vs_tl.png", dpi=200, bbox_inches="tight")

# --- Summary table (slide-friendly) ---
summary = pd.DataFrame([
    {
        "Experiment": "Baseline (from scratch)",
        "Best Val Dice": b_best,
        "Best Epoch": b_best_ep,
        "Final Val Dice": float(b_val[-1]),
        "Final Train Dice": float(baseline_history["train_dice"][-1]),
    },
    {
        "Experiment": "Transfer Learning (pretrained encoder)",
        "Best Val Dice": t_best,
        "Best Epoch": t_best_ep,
        "Final Val Dice": float(t_val[-1]),
        "Final Train Dice": float(tl_history["train_dice"][-1]),
    },
])

display(summary)
# Out:
#                                Experiment  Best Val Dice  Best Epoch  \
# 0                 Baseline (from scratch)       0.684289          13
# 1  Transfer Learning (pretrained encoder)       0.765513          14
#
#    Final Val Dice  Final Train Dice
# 0        0.684262          0.685128
# 1        0.748349          0.791832

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def best_epoch(vals):
    vals = np.array(vals, dtype=float)
    i = int(np.argmax(vals))
    return i+1, float(vals[i])

# ---- Gather (rename if your variables differ) ----
histories = {
    "BCE + Dice": tl_history,        # pretrained reference
    "Focal": focal_history,
    "Tversky": tversky_history,
}

# ---- 1) Curve: Val Dice vs Epoch ----
plt.figure(figsize=(8,4))
for name, h in histories.items():
    v = h["val_dice"]
    e = np.arange(1, len(v)+1)
    plt.plot(e, v, marker="o", label=name)

plt.xlabel("Epoch")
plt.ylabel("Validation Dice")
plt.title("Validation Dice: Loss function comparison (pretrained U-Net)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Save for Canva (optional)
# plt.savefig("val_dice_loss_comparison.png", dpi=200, bbox_inches="tight")

# ---- 2) Best-score table (slide-friendly) ----
rows = []
for name, h in histories.items():
    ep, best = best_epoch(h["val_dice"])
    rows.append({
        "Loss": name,
        "Best Val Dice": best,
        "Best Epoch": ep,
        "Final Val Dice": float(h["val_dice"][-1]),
    })

df = pd.DataFrame(rows).sort_values("Best Val Dice", ascending=False).reset_index(drop=True)
display(df)

# ---- 3) (Optional) Bar chart of best Val Dice ----
plt.figure(figsize=(6,4))
plt.bar(df["Loss"], df["Best Val Dice"])
plt.ylabel("Best Validation Dice")
plt.title("Best Validation Dice by loss")
plt.grid(True, axis="y")
plt.tight_layout()
plt.show()

# Save for Canva (optional)
# plt.savefig("best_val_dice_by_loss.png", dpi=200, bbox_inches="tight")
# Out:
#          Loss  Best Val Dice  Best Epoch  Final Val Dice
# 0     Tversky       0.766362          13        0.763769
# 1  BCE + Dice       0.765513          14        0.748349
# 2       Focal       0.740951          15        0.740951
